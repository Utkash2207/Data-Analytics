# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkash2207/Data-Analytics/blob/main/project_PBL_II_Assingment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/bikes.csv')
df
# Out:
#                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# 0     first owner    hyderabad  \n\n 35 kmpl     19 bhp   63500
# ...

# %%
df.isnull().sum()
# Out:
# model_name     0
# model_year     0
# kms_driven     0
# owner          0
# location      19
# mileage       11
# power         31
# price          0
# dtype: int64

# %%
df.dropna(inplace =True)

# %%
df.isnull().sum()
# Out:
# model_name    0
# model_year    0
# kms_driven    0
# owner         0
# location      0
# mileage       0
# power         0
# price         0
# dtype: int64

# %%
sns.countplot(x = df['model_year'])
# Out:
# <Axes: xlabel='model_year', ylabel='count'>

# %%
sns.boxplot(x = df['location'])
# Out:
# <Axes: xlabel='location'>

# %%
sns.displot(df['location'])

# %%
sns.countplot(x=df['kms_driven'])
# Out:
# <Axes: xlabel='kms_driven', ylabel='count'>

# %%
df
# Out:
#                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# 0     first owner    hyderabad  \n\n 35 kmpl     19 bhp   63500
# ...

# %%
df.describe(include = "object")
# Out:
#                               model_name       kms_driven        owner  \
# count                               7796             7796         7796
# unique                              1700             1785            4
# top     Royal Enfield Classic 350cc 2017  Mileage 65 Kmpl  first owner
# freq                                  78              434         6767
#
#        location       mileage      power
# count      7796          7796       7796
# unique      558           116        262
# top       delhi  \n\n 35 kmpl  19.80 bhp
# freq       1432          1067        921

# %%
df['location'].value_counts()
# Out:
# location
# delhi           1432
# mumbai           851
# bangalore        776
# pune             340
# hyderabad        335
#                 ...
# tonk               1
# jhabua             1
# aluva              1
# irinjalakuda       1
# sidlaghatta        1
# Name: count, Length: 558, dtype: int64

# %%
df.groupby('location')['model_year'].value_counts().unstack().plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='location'>

# %%
df.groupby('model_year')['location'].value_counts().unstack().plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='model_year'>

# %%
plt.pie(x=df['owner'].value_counts())
plt.show()
